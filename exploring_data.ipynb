# %%
import pandas as pd
geo_df= pd.read_csv("./data/new dataset.csv")
geo_df.head()
# Out:
#                  DateTime  Latitude  Longitude   Depth  Magnitude MagType  \
# 0  1991/01/08 02:10:28.17  38.79767 -122.77800  -0.227       3.10      ML
# 1  1991/01/09 22:09:04.80  35.90550 -120.44900   5.759       3.13      Md
# 2  1991/01/10 21:55:10.89  39.18550 -119.79533   7.050       2.64      Md
# 3  1991/01/11 16:07:13.98  40.44600 -126.16116   1.742       2.87      Md
# 4  1991/01/11 22:30:46.75  40.42683 -124.61517  22.998       3.30      ML
#
#    NbStations  Gap  Distance   RMS Source  EventID
# 0          44   36         2  0.07   NCSN   204323
# 1          50   59         3  0.05   NCSN   204449
# 2          36  220        87  0.12   NCSN   204520
# 3          17  313       155  0.10   NCSN   204580
# 4          45  231        24  0.08   NCSN   204589

# %%
moma_df= pd.read_csv("./data/moma_artworks_cleaned.csv")
moma_df.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa project, outside Vienna, Austria (Elevat...
# 3  Villa project, outside Vienna, Austria (Exteri...
# 4  Memorial to the Six Million Jewish Martyrs, pr...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3                Emil Hoppe          7605
# 4             Louis I. Kahn          2964
#
#                              ArtistBio Nationality BeginDate EndDate  Gender  \
# 0                (Austrian, 1841–1918)    Austrian    (1841)  (1918)  (male)
# 1                  (French, born 1944)      French    (1944)     (0)  (male)
# 2                (Austrian, 1876–1957)    Austrian    (1876)  (1957)  (male)
# ...

# %%
moma_df['Nationality'].unique()
# Out:
# array(['Austrian', 'French', 'American', 'German', 'Dutch', 'Italian',
#        'Swedish', 'British', 'Japanese', 'Argentine', 'Brazilian',
#        'Swiss', 'Luxembourger', 'Spanish', 'Russian', 'Iranian',
#        'Canadian', 'Finnish', 'Danish', 'Belgian', 'Czech', 'Moroccan',
#        'Coptic', 'Persian', 'Colombian', 'Australian', 'Chinese',
#        'Mexican', 'Slovenian', 'Hungarian', 'Polish', 'Chilean',
#        'Latvian', 'Greek', 'Israeli', 'Czechoslovakian', 'Icelandic',
#        'Croatian', 'Norwegian', 'Georgian', 'Ukrainian', 'Yugoslavian',
#        'Cuban', 'Romanian', 'Venezuelan', 'Uruguayan', 'Thai', 'Algerian',
#        'Serbian', 'Guatemalan', 'Indian', 'Irish', 'Korean', 'Ethiopian',
#        'Kuwaiti', 'Haitian', 'Scottish', 'Zimbabwean', 'Ecuadorian',
#        'Portuguese', 'Panamanian', 'Peruvian', 'Congolese', 'Azerbaijani',
#        'Malian', 'Turkish', 'Bosnian', 'Slovak', 'Estonian', 'Pakistani',
# ...

# %%
nationality_to_country = {
    "Austrian": "Austria",
    "French": "France",
    "American": "United States",
    "German": "Germany",
    "Dutch": "Netherlands",
    "Italian": "Italy",
    "Swedish": "Sweden",
    "British": "United Kingdom",
    "Japanese": "Japan",
    "Argentine": "Argentina",
    "Brazilian": "Brazil",
    "Swiss": "Switzerland",
    "Luxembourger": "Luxembourg",
    "Spanish": "Spain",
    "Russian": "Russia",
    "Iranian": "Iran",
    "Canadian": "Canada",
    "Finnish": "Finland",
    "Danish": "Denmark",
    "Belgian": "Belgium",
    "Czech": "Czech Republic",
    "Moroccan": "Morocco",
    "Coptic": "Egypt",
    "Persian": "Iran",
    "Colombian": "Colombia",
    "Australian": "Australia",
    "Chinese": "China",
    "Mexican": "Mexico",
    "Slovenian": "Slovenia",
    "Hungarian": "Hungary",
    "Polish": "Poland",
    "Chilean": "Chile",
    "Latvian": "Latvia",
    "Greek": "Greece",
    "Israeli": "Israel",
    "Czechoslovakian": "Czechoslovakia",
    "Icelandic": "Iceland",
    "Croatian": "Croatia",
    "Norwegian": "Norway",
    "Georgian": "Georgia",
    "Ukrainian": "Ukraine",
    "Yugoslavian": "Yugoslavia",
    "Cuban": "Cuba",
    "Romanian": "Romania",
    "Venezuelan": "Venezuela",
    "Uruguayan": "Uruguay",
    "Thai": "Thailand",
    "Algerian": "Algeria",
    "Serbian": "Serbia",
    "Guatemalan": "Guatemala",
    "Indian": "India",
    "Irish": "Ireland",
    "Korean": "South Korea",
    "Ethiopian": "Ethiopia",
    "Kuwaiti": "Kuwait",
    "Haitian": "Haiti",
    "Scottish": "United Kingdom",
    "Zimbabwean": "Zimbabwe",
    "Ecuadorian": "Ecuador",
    "Portuguese": "Portugal",
    "Panamanian": "Panama",
    "Peruvian": "Peru",
    "Congolese": "Democratic Republic of the Congo",
    "Azerbaijani": "Azerbaijan",
    "Malian": "Mali",
    "Turkish": "Turkey",
    "Bosnian": "Bosnia and Herzegovina",
    "Slovak": "Slovakia",
    "Estonian": "Estonia",
    "Pakistani": "Pakistan",
    "Jamaican": "Jamaica",
    "Bulgarian": "Bulgaria",
    "Bolivian": "Bolivia",
    "Palestinian": "Palestine",
    "Taiwanese": "Taiwan",
    "Paraguayan": "Paraguay",
    "Uzbekistan": "Uzbekistan",
    "Nicaraguan": "Nicaragua",
    "Tunisian": "Tunisia",
    "Sudanese": "Sudan",
    "Tanzanian": "Tanzania",
    "Senegalese": "Senegal",
    "Bahamian": "Bahamas",
    "Lebanese": "Lebanon",
    "Kenyan": "Kenya",
    "Nigerian": "Nigeria",
    "Egyptian": "Egypt",
    "Albanian": "Albania",
    "Ivorian": "Ivory Coast",
    "Malaysian": "Malaysia",
    "Singaporean": "Singapore",
    "Lithuanian": "Lithuania",
    "Namibian": "Namibia",
    "Ghanaian": "Ghana",
    "Afghan": "Afghanistan",
    "Ugandan": "Uganda",
    "Cameroonian": "Cameroon",
    "Welsh": "United Kingdom",
    "Catalan": "Spain",
    "Vietnamese": "Vietnam",
    "Macedonian": "North Macedonia",
    "Filipino": "Philippines",
    "Syrian": "Syria",
    "Bangladeshi": "Bangladesh",
    "Burkinabé": "Burkina Faso",
    "Beninese": "Benin",
    "Emirati": "United Arab Emirates",
    "Salvadoran": "El Salvador",
    "Iraqi": "Iraq",
    "Mozambican": "Mozambique",
    "Caribbean": "Caribbean Region",
    "English": "United Kingdom",
    "Indonesian": "Indonesia",
    "Ivatan": "Philippines",
    "Nepali": "Nepal",
    "Oneida": "United States"
}

# %%
moma_df['Country'] = moma_df['Nationality'].map(nationality_to_country)
moma_df.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa project, outside Vienna, Austria (Elevat...
# 3  Villa project, outside Vienna, Austria (Exteri...
# 4  Memorial to the Six Million Jewish Martyrs, pr...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3                Emil Hoppe          7605
# 4             Louis I. Kahn          2964
#
#                              ArtistBio Nationality BeginDate EndDate  Gender  \
# 0                (Austrian, 1841–1918)    Austrian    (1841)  (1918)  (male)
# 1                  (French, born 1944)      French    (1944)     (0)  (male)
# 2                (Austrian, 1876–1957)    Austrian    (1876)  (1957)  (male)
# ...

# %%
moma_df['Country'].unique()
# Out:
# array(['Austria', 'France', 'United States', 'Germany', 'Netherlands',
#        'Italy', 'Sweden', 'United Kingdom', 'Japan', 'Argentina',
#        'Brazil', 'Switzerland', 'Luxembourg', 'Spain', 'Russia', 'Iran',
#        'Canada', 'Finland', 'Denmark', 'Belgium', 'Czech Republic',
#        'Morocco', 'Egypt', 'Colombia', 'Australia', 'China', 'Mexico',
#        'Slovenia', 'Hungary', 'Poland', 'Chile', 'Latvia', 'Greece',
#        'Israel', 'Czechoslovakia', 'Iceland', 'Croatia', 'Norway',
#        'Georgia', 'Ukraine', 'Yugoslavia', 'Cuba', 'Romania', 'Venezuela',
#        'Uruguay', 'Thailand', 'Algeria', 'Serbia', 'Guatemala', 'India',
#        'Ireland', 'South Korea', 'Ethiopia', 'Kuwait', 'Haiti',
#        'Zimbabwe', 'Ecuador', 'Portugal', 'Panama', 'Peru',
#        'Democratic Republic of the Congo', 'Azerbaijan', 'Mali', 'Turkey',
#        'Bosnia and Herzegovina', 'Slovakia', 'Estonia', 'Pakistan',
#        'Jamaica', 'Bulgaria', 'Bolivia', 'Palestine', 'Taiwan',
# ...

# %%
country_to_latlon = {
    "Austria": (47.5162, 14.5501),
    "France": (46.2276, 2.2137),
    "United States": (39.8283, -98.5795),
    "Germany": (51.1657, 10.4515),
    "Netherlands": (52.1326, 5.2913),
    "Italy": (41.8719, 12.5674),
    "Sweden": (60.1282, 18.6435),
    "United Kingdom": (55.3781, -3.4360),
    "Japan": (36.2048, 138.2529),
    "Argentina": (-38.4161, -63.6167),
    "Brazil": (-14.2350, -51.9253),
    "Switzerland": (46.8182, 8.2275),
    "Luxembourg": (49.8153, 6.1296),
    "Spain": (40.4637, -3.7492),
    "Russia": (61.5240, 105.3188),
    "Iran": (32.4279, 53.6880),
    "Canada": (56.1304, -106.3468),
    "Finland": (61.9241, 25.7482),
    "Denmark": (56.2639, 9.5018),
    "Belgium": (50.5039, 4.4699),
    "Czech Republic": (49.8175, 15.4730),
    "Morocco": (31.7917, -7.0926),
    "Egypt": (26.8206, 30.8025),
    "Colombia": (4.5709, -74.2973),
    "Australia": (-25.2744, 133.7751),
    "China": (35.8617, 104.1954),
    "Mexico": (23.6345, -102.5528),
    "Slovenia": (46.1512, 14.9955),
    "Hungary": (47.1625, 19.5033),
    "Poland": (51.9194, 19.1451),
    "Chile": (-35.6751, -71.5430),
    "Latvia": (56.8796, 24.6032),
    "Greece": (39.0742, 21.8243),
    "Israel": (31.0461, 34.8516),
    "Czechoslovakia": (49.8175, 15.4730),
    "Iceland": (64.9631, -19.0208),
    "Croatia": (45.1000, 15.2000),
    "Norway": (60.4720, 8.4689),
    "Georgia": (42.3154, 43.3569),
    "Ukraine": (48.3794, 31.1656),
    "Yugoslavia": (44.0165, 21.0059),
    "Cuba": (21.5218, -77.7812),
    "Romania": (45.9432, 24.9668),
    "Venezuela": (6.4238, -66.5897),
    "Uruguay": (-32.5228, -55.7658),
    "Thailand": (15.8700, 100.9925),
    "Algeria": (28.0339, 1.6596),
    "Serbia": (44.0165, 21.0059),
    "Guatemala": (15.7835, -90.2308),
    "India": (20.5937, 78.9629),
    "Ireland": (53.4129, -8.2439),
    "South Korea": (35.9078, 127.7669),
    "Ethiopia": (9.1450, 40.4897),
    "Kuwait": (29.3117, 47.4818),
    "Haiti": (18.9712, -72.2852),
    "Zimbabwe": (-19.0154, 29.1549),
    "Ecuador": (-1.8312, -78.1834),
    "Portugal": (39.3999, -8.2245),
    "Panama": (8.5380, -80.7821),
    "Peru": (-9.1900, -75.0152),
    "Democratic Republic of the Congo": (-4.0383, 21.7587),
    "Azerbaijan": (40.1431, 47.5769),
    "Mali": (17.5707, -3.9962),
    "Turkey": (38.9637, 35.2433),
    "Bosnia and Herzegovina": (43.9159, 17.6791),
    "Slovakia": (48.6690, 19.6990),
    "Estonia": (58.5953, 25.0136),
    "Pakistan": (30.3753, 69.3451),
    "Jamaica": (18.1096, -77.2975),
    "Bulgaria": (42.7339, 25.4858),
    "Bolivia": (-16.2902, -63.5887),
    "Palestine": (31.9522, 35.2332),
    "Taiwan": (23.6978, 120.9605),
    "Paraguay": (-23.4425, -58.4438),
    "Uzbekistan": (41.3775, 64.5853),
    "Nicaragua": (12.8654, -85.2072),
    "Tunisia": (33.8869, 9.5375),
    "Sudan": (12.8628, 30.2176),
    "Tanzania": (-6.3690, 34.8888),
    "Senegal": (14.4974, -14.4524),
    "Bahamas": (25.0343, -77.3963),
    "Lebanon": (33.8547, 35.8623),
    "Kenya": (-0.0236, 37.9062),
    "Nigeria": (9.0820, 8.6753),
    "Albania": (41.1533, 20.1683),
    "Ivory Coast": (7.5400, -5.5471),
    "Malaysia": (4.2105, 101.9758),
    "Singapore": (1.3521, 103.8198),
    "Lithuania": (55.1694, 23.8813),
    "Namibia": (-22.9576, 18.4904),
    "Ghana": (7.9465, -1.0232),
    "Afghanistan": (33.9391, 67.7100),
    "Uganda": (1.3733, 32.2903),
    "Cameroon": (7.3697, 12.3547),
    "Vietnam": (14.0583, 108.2772),
    "North Macedonia": (41.6086, 21.7453),
    "Philippines": (12.8797, 121.7740),
    "Syria": (34.8021, 38.9968),
    "Bangladesh": (23.6850, 90.3563),
    "Burkina Faso": (12.2383, -1.5616),
    "Benin": (9.3077, 2.3158),
    "United Arab Emirates": (23.4241, 53.8478),
    "El Salvador": (13.7942, -88.8965),
    "Iraq": (33.2232, 43.6793),
    "Mozambique": (-18.6657, 35.5296),
    "Caribbean Region": (18.2208, -66.5901),
    "Indonesia": (-0.7893, 113.9213),
    "Nepal": (28.3949, 84.1240)
}

# %%
moma_df[['Latitude', 'Longitude']] = (
    moma_df['Country']
    .map(country_to_latlon)
    .apply(pd.Series)
)

# %%
moma_df.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa project, outside Vienna, Austria (Elevat...
# 3  Villa project, outside Vienna, Austria (Exteri...
# 4  Memorial to the Six Million Jewish Martyrs, pr...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3                Emil Hoppe          7605
# 4             Louis I. Kahn          2964
#
#                              ArtistBio Nationality BeginDate EndDate  Gender  \
# 0                (Austrian, 1841–1918)    Austrian    (1841)  (1918)  (male)
# 1                  (French, born 1944)      French    (1944)     (0)  (male)
# 2                (Austrian, 1876–1957)    Austrian    (1876)  (1957)  (male)
# ...

# %%
moma_df.to_csv('moma_artworks_geodata.csv', index=False)

# %%
moma_df[moma_df["Nationality"]=="American"]
# Out:
#                                                     Title  \
# 4       Memorial to the Six Million Jewish Martyrs, pr...
# 9                              Earth-Cloud House, project
# 10      House IV Project, Falls Village, Connecticut (...
# 12      Pedestrian City project, Hypostyle Courtyard (...
# 13      Pedestrian City project, Hypostyle Courtyard (...
# ...                                                   ...
# 147529  Resor House project, Jackson Hole, WY (J.B. Ro...
# 147530  Resor House project, Jackson Hole, WY (J.B. Ro...
# 147531  Resor House project, Jackson Hole, WY (J.B. Ro...
# 147532  Resor House project, Jackson Hole, WY (J.B. Ro...
# 147533  Resor House project, Jackson Hole, WY (J.B. Ro...
#
#                              Artist ConstituentID  \
# 4                     Louis I. Kahn          2964
# 9                   Raimund Abraham            47
# 10      Peter Eisenman, Robert Cole    6969, 8134
# 12                   Roger C. Ferri          1863
# ...

# %%
# clena the date column

import pandas as pd
moma_df= pd.read_csv('moma_artworks_geodata.csv')
moma_df["Date"] = moma_df["Date"].astype(str).str.extract(r'(\d{4})')

moma_df.sample(40)
# Out:
# /tmp/ipykernel_99127/565776613.py:4: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   moma_df= pd.read_csv('moma_artworks_geodata.csv')
#                                                     Title  \
# 136915  IIT Commons Building, Chicago, IL (Doors. Elev...
# 81914               Drawing for 'Dream of Opposite World'
# 55219                                     PORTABLE SHRINE
# 226403  Jacquard loom punched cards for the fabric boo...
# 122415  Portrait of La Monte Young (page 1) from Fluxus 1
# 182085                      How Did Charlie Know the Way?
# 164096                      How Did Charlie Know the Way?
# 224004  Jacquard loom punched cards for the fabric boo...
# 165859                      How Did Charlie Know the Way?
# 218645  Jacquard loom punched cards for the fabric boo...
# 15679                Plate (folio 48) from Elephant Skull
# 96096                Markelius fabric sample (model K288)
# ...

# %%
moma_df.to_csv('moma_artworks_geodata_cleaned.csv', index=False)
